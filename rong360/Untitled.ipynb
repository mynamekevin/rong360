# %%
#coding=utf-8



import pandas as pd 
import os


files = os.listdir('featurescore')
fs = {}
for f in files:
    t = pd.read_csv('featurescore/'+f)
    t.index = t.feature
    t = t.drop(['feature'],axis=1)
    d = t.to_dict()['score']
    for key in d:
        if fs.has_key(key):
            fs[key] += d[key]
        else:
            fs[key] = d[key] 
            
fs = sorted(fs.items(), key=lambda x:x[1],reverse=True)

t = []
for (key,value) in fs:
    t.append("{0},{1}\n".format(key,value))

with open('feature_score.csv','w') as f:
    f.writelines("feature,score\n")
    f.writelines(t)

t
# Out:
# ['browse_countAvgMon,65644\n',
#  'bill_prior_repayCaccount_topMean,59912\n',
#  'bill_limit-account_mean,59668\n',
#  'browse_meanAvgMon,54388\n',
#  'bill_minimunRepay_mean,47512\n',
#  'bill_accountBalance_mean,46669\n',
#  'bill_limit-account_topMean,43917\n',
#  'browse_count,41645\n',
#  'bill_priorRepay_mean,38424\n',
#  'bill_account_monthAvg,37701\n',
#  'bill_minimunRepay_pctSum,37593\n',
#  'bill_priorAccount_mean,37315\n',
#  'bill_countbank_id,34751\n',
#  'bill_priorRepay_max,34594\n',
#  'bill_prior_repayCaccount_mean,34468\n',
#  'browse_tag_5,33409\n',
#  'bill_limitSum,33151\n',
#  'browse_tag_10,32064\n',
#  'browse_tag_7,31615\n',
#  'browse_tag_1,31442\n',
#  'bill_priorAccount_max,30195\n',
#  'browse_tag_6,29768\n',
#  'bill_priorRepay_pctSum,29765\n',
#  'browse_tag_4,28236\n',
#  'bill_account_pctSum,27926\n',
#  'bill_minimunRepay_std,27056\n',
#  'bill_accountBalance_std,26937\n',
#  'browse_tag_8,26840\n',
#  'bill_accountBalance_pctSum,26189\n',
#  'bill_account_std,25100\n',
#  'bill_priorAccount_pctSum,25099\n',
#  'bill_priorRepay_std,24637\n',
#  'bill_priorAccount_std,24303\n',
#  'bill_limitMean,22596\n',
#  'bill_count_monthAvg,21853\n',
#  'bill_limitStd,21835\n',
#  'bill_account_pctSumAbs,19678\n',
#  'bill_priorRepayCAccount_std,18745\n',
#  'browse_tag_3,17282\n',
#  'household,13943\n',
#  'sex,13751\n',
#  'education,11921\n',
#  'occupation,11724\n',
#  'marriage,11399\n',
#  'browse_tag_9,2570\n',
#  'bill_bankid_count,1463\n',
#  'browse_tag_11,185\n',
#  'browse_tag_2,86\n']

# %%
files = os.listdir('featurescore_rank')
fs = {}
for f in files:
    t = pd.read_csv('featurescore_rank/'+f)
    t.index = t.feature
    t = t.drop(['feature'],axis=1)
    d = t.to_dict()['score']
    for key in d:
        if fs.has_key(key):
            fs[key] += d[key]
        else:
            fs[key] = d[key] 
            
fs = sorted(fs.items(), key=lambda x:x[1],reverse=True)

tr = []
for (key,value) in fs:
    tr.append("{0},{1}\n".format(key,value))

with open('rank_feature_score.csv','w') as f:
    f.writelines("feature,score\n")
    f.writelines(tr)
tr
# Out:
# ['r_browse_countAvgMon,65014\n',
#  'r_bill_prior_repayCaccount_topMean,59379\n',
#  'r_bill_limit-account_mean,58685\n',
#  'r_browse_meanAvgMon,53044\n',
#  'r_bill_minimunRepay_mean,47328\n',
#  'r_bill_accountBalance_mean,45963\n',
#  'r_bill_limit-account_topMean,42994\n',
#  'r_browse_count,40995\n',
#  'r_bill_priorRepay_mean,38008\n',
#  'r_bill_priorAccount_mean,37098\n',
#  'r_bill_account_monthAvg,37014\n',
#  'r_bill_minimunRepay_pctSum,36375\n',
#  'r_bill_priorRepay_max,34058\n',
#  'r_bill_prior_repayCaccount_mean,34048\n',
#  'r_bill_countbank_id,33876\n',
#  'r_browse_tag_5,33092\n',
#  'r_bill_limitSum,32102\n',
#  'r_browse_tag_10,31866\n',
#  'r_browse_tag_7,30856\n',
#  'r_browse_tag_1,30709\n',
#  'r_bill_priorAccount_max,29554\n',
#  'r_bill_priorRepay_pctSum,29319\n',
#  'r_browse_tag_6,29186\n',
#  'r_bill_account_pctSum,27466\n',
#  'r_browse_tag_4,27219\n',
#  'r_bill_minimunRepay_std,26597\n',
#  'r_browse_tag_8,26416\n',
#  'r_bill_accountBalance_std,26244\n',
#  'r_bill_accountBalance_pctSum,26110\n',
#  'r_bill_priorAccount_pctSum,24643\n',
#  'r_bill_priorAccount_std,24514\n',
#  'r_bill_account_std,24392\n',
#  'r_bill_priorRepay_std,24232\n',
#  'r_bill_limitStd,22281\n',
#  'r_bill_limitMean,22079\n',
#  'r_bill_count_monthAvg,21678\n',
#  'r_bill_account_pctSumAbs,19183\n',
#  'r_bill_priorRepayCAccount_std,18302\n',
#  'r_browse_tag_3,16771\n',
#  'r_household,13819\n',
#  'r_sex,13464\n',
#  'r_education,11920\n',
#  'r_occupation,11353\n',
#  'r_marriage,11081\n',
#  'r_browse_tag_9,2664\n',
#  'r_bill_bankid_count,1343\n',
#  'r_browse_tag_11,187\n',
#  'r_browse_tag_2,83\n']
